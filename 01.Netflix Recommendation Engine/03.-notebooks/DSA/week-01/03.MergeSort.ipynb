# %%
# imports the pandas library, used for data analysis and handling CSV/Excel files
import pandas as pd

# %%
df= pd.read_csv("C:/Users/jovit/Desktop/Netflix_Project/netflix_titles_clean.csv")
# loads the Netflix dataset CSV into a pandas DataFrame called df
# DataFrame = table-like structure (rows & columns) for easy analysis

# %%
print(df.shape) # shows (rows, columns)
# Out:
# (8807, 13)

# %%
print(df.info) # shows column names and few rows
# Out:
# <bound method DataFrame.info of      show_id show_type                  title         director  \
# 0         s1     Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2   TV Show          Blood & Water          Unknown
# 2         s3   TV Show              Ganglands  Julien Leclercq
# 3         s4   TV Show  Jailbirds New Orleans          Unknown
# 4         s5   TV Show           Kota Factory          Unknown
# ...      ...       ...                    ...              ...
# 8802   s8803     Movie                 Zodiac    David Fincher
# 8803   s8804   TV Show            Zombie Dumb          Unknown
# 8804   s8805     Movie             Zombieland  Ruben Fleischer
# 8805   s8806     Movie                   Zoom     Peter Hewitt
# 8806   s8807     Movie                 Zubaan      Mozez Singh
#
#                                               cast_name        country  \
# 0                                         Not Available  United States
# ...

# %%
#check the columns 
print(df.columns.tolist())
# Out:
# ['show_id', 'show_type', 'title', 'director', 'cast_name', 'country', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description', 'added_year']

# %%
years = df["release_year"].tolist()
print(years)
# Out:
# [2020, 2021, 2021, 2021, 2021, 2021, 2021, 1993, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2020, 2020, 2021, 2021, 2021, 2018, 1996, 2021, 1998, 2021, 1997, 2010, 2013, 2013, 2021, 2021, 2020, 2021, 2020, 2021, 2021, 2018, 2017, 2021, 2021, 1975, 1978, 1983, 1987, 2021, 2012, 2020, 2001, 2021, 2014, 2002, 2003, 2004, 2001, 2021, 2011, 2008, 2009, 2007, 2010, 2005, 2006, 2004, 2021, 2021, 2014, 1994, 2021, 2015, 2021, 2021, 2021, 2018, 2021, 2021, 2013, 2021, 2020, 2021, 2021, 2021, 2021, 2021, 2020, 2021, 2021, 2019, 2021, 2017, 2019, 2021, 2021, 2021, 2018, 2021, 2018, 2021, 2021, 2021, 2019, 2021, 2021, 2020, 2016, 2017, 2021, 2018, 2021, 2021, 2021, 2021, 2021, 2021, 1994, 2009, 2015, 2021, 2017, 2020, 2021, 2019, 2003, 2012, 2013, 2021, 2020, 2004, 2017, 2005, 2021, 1982, 2021, 2015, 1994, 1993, 2003, 2001, 2010, 1989, 2014, 2015, 2007, 2011, 1990, 1991, 1994, 2021, 2020, 1998, 1999, 2005, 2016, 2016, 2015, 1986, 2010, 2018, 2003, 2010, 1992, 1996, 2017, 2003, 1999, 2019, 1
# ...

# %%
# Merge-sort Algorithm
# Example 1: Sort release years
def merge_sort(arr):

    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2

    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)


def merge(left, right):

    result = []

    i = 0
    j = 0

    while i < len(left) and j < len(right):

        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])

    return result


sorted_years = merge_sort(years)

print(sorted_years[:10])
# Out:
# [1925, 1942, 1942, 1943, 1943, 1943, 1944, 1944, 1944, 1945]

# %%
#Merge-sort Algorithm 
#Example 2: Sort Movies by Release Year
movies = list(zip(df["title"], df["release_year"]))

def merge(left, right):

    result = []
    i = j = 0

    while i < len(left) and j < len(right):

        if left[i][1] <= right[j][1]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])

    return result

# %%
#Output of the sorted movies by release year 
sorted_movies = merge_sort(movies)

for movie in sorted_movies[:10]:
    print(movie)
# Out:
# ('Pioneers: First Women Filmmakers*', 1925)
# ('Prelude to War', 1942)
# ('The Battle of Midway', 1942)
# ('Undercover: How to Operate Behind Enemy Lines', 1943)
# ('Why We Fight: The Battle of Russia', 1943)
# ('WWII: Report from the Aleutians', 1943)
# ('The Memphis Belle: A Story of a\nFlying Fortress', 1944)
# ('The Negro Soldier', 1944)
# ('Tunisian Victory', 1944)
# ('Five Came Back: The Reference Films', 1945)
