# %%
# Day 2 - Netflix Dataset Journey
## Searching Algorithms (Linear & Binary)

# %%
import psycopg2       #to connect to PostgreSQL
import pandas as pd   # to handles tables nicely

# %%
conn = psycopg2.connect(
    dbname="netflix_db",
    user="postgres",       # your username
    password="jovita", # replace with your password
    host="localhost",      # or 127.0.0.1
    port="5432"            # default PostgreSQL port
)

# %%
# Example: fetch first 10 rows from ratings table
df_ratings = pd.read_sql("SELECT * FROM ratings LIMIT 10;", conn)
df_ratings
# Out:
# C:\Users\jovit\AppData\Local\Temp\ipykernel_4800\669458072.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_ratings = pd.read_sql("SELECT * FROM ratings LIMIT 10;", conn)
#    rating_id show_id  user_id  rating
# 0          1      s1      549       6
# 1          2      s2       26       3
# 2          3      s3      505       5
# 3          4      s4      625       4
# 4          5      s5      117       3
# 5          6      s6      204       4
# 6          7      s7       83       4
# 7          8      s8      392       2
# 8          9      s9      266       4
# 9         10     s10      300       3

# %%
df = pd.read_csv("C:/Users/jovit/Desktop/Netflix_Project/netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
conn.rollback()

# %%
with open("C:/Users/jovit/Desktop/Netflix_Project/SQL/day2_queries.sql", "r") as file:
    sql_script = file.read()

# Split into individual statements
queries = sql_script.split(";")

cursor = conn.cursor()
for query in queries:
    if "CREATE TABLE" not in query:   # skip table creation
        if query.strip() != "":
            cursor.execute(query)
conn.commit()
cursor.close()

# %%
## Problem Statement
We want to search for a rating inside a list of Netflix ratings.
We will use two algorithms:
1. Linear Search
2. Binary Search

# %%
### Linear Search
Linear search checks each element one by one until it finds the target.

# %%
# Linear search checks each element one by one
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:   # compare each element with target
            return i           # return index if found
    return -1                  # return -1 if not found

# Example usage
ratings = [3, 5, 2, 4, 1]
print("Target found at index:", linear_search(ratings, 4))  # Output: 3
# Out:
# Target found at index: 3

# %%
### Binary Search
Binary search is faster but requires the list to be sorted.

# %%
#Binary search requires sorted data
def binary_search(arr, target):
    low, high = 0, len(arr)-1
    while low <= high:
        mid = (low+high)//2
        if arr[mid]==target:
            return mid
        elif arr[mid]<target:
            low = mid +1 
        else:
            high = mid -1
    return
   # Example usage
ratings = sorted([3, 5, 2, 4, 1])  # must sort first
print("Target found at index:", binary_search(ratings, 4))  # Output: 3
# Out:
# Target found at index: 3
